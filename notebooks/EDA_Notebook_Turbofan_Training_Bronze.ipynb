# %%
import os
import glob
from pathlib import Path
import yaml

import logging

import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 

from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.ensemble import RandomForestClassifier, IsolationForest
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score

# Show more columns
pd.set_option("display.max_columns", 100)
pd.set_option("display.width", 200)

# Initiate Logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# %%
def get_directories():

    # Get Current Working Directory
    CWD = Path().resolve()

    # 
    # Priority: ENV → script → Jupyter fallback
    env_root = os.getenv("APP_ROOT")

    if env_root:
        APP_ROOT = Path(env_root).resolve()

    else:
        try:
            # Script Path
            APP_ROOT = Path(__file__).resolve().parents[1]
        except NameError:
            # Notebook execution path
            APP_ROOT = CWD.parent

    # Set Data Directory
    DATA_DIR = APP_ROOT / "data"

    # Log everything for debugging
    logger.info(f"CWD:             {CWD}")
    logger.info(f"APP_ROOT:        {APP_ROOT}")
    logger.info(f"DATA Directory:  {DATA_DIR}")

    return APP_ROOT, DATA_DIR

#### #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### 

def load_data(DATA_PATH, DATA_FILE, **kwargs):

    """
        Load data file with
    """

    try:
        data = pd.read_csv(DATA_PATH/DATA_FILE, **kwargs)
        logger.info(f"Data File Loaded: {data.info()}")
        return data

    except Exception as e:
        print(f"Error reading CSV file: {e}")
        return None

    
    #### #### #### #### #### #### #### #### #### #### #### #### #### #### #### ####

# %%
# Global Variables

# Folder Locations
APP_ROOT, DATA_DIR = get_directories()

RAW_DATA_DIR = DATA_DIR / "raw"
RAW_DATA_SUBDIR = "NASA_Turbofan_Jet_Engine_Dataset/CMaps"

RAW_DATA_PATH = RAW_DATA_DIR / RAW_DATA_SUBDIR

BRONZE_DATA_DIR = DATA_DIR / "bronze"
BRONZE_DATA_FILE_NAME = "turbofan_train_bronze.csv"
BRONZE_DATA_OUTPUT_PATH = BRONZE_DATA_DIR / BRONZE_DATA_FILE_NAME
# Out:
# INFO:__main__:CWD:             /notebooks
# INFO:__main__:APP_ROOT:        /
# INFO:__main__:DATA Directory:  /data

# %%
print(RAW_DATA_PATH)
# Out:
# /data/raw/NASA_Turbofan_Jet_Engine_Dataset/CMaps

# %%
# There are 26 columns in the dataset. 
# The first five columns have a different format then the remaining 21. 
# We will addresss these columns first then add in the remainingg 21. 

# Creating column name list for the first five. 
COLUMN_NAMES = [
    "unit",
    "cycle",
    "op_setting_1",
    "op_setting_2",
    "op_setting_3",
]

# As stated the remaining 21 columns share a similar name structure of sensor then a number
# So we will generate them using a loop and appended them to our list:
COLUMN_NAMES += [f"s{i}" for i in range(1, 22)]

# Display Column Names to verify success.
len(COLUMN_NAMES), COLUMN_NAMES[:10]
# Out:
# (26,
#  ['unit',
#   'cycle',
#   'op_setting_1',
#   'op_setting_2',
#   'op_setting_3',
#   's1',
#   's2',
#   's3',
#   's4',
#   's5'])

# %%
# Load Data Import Keywords/Additional parameters.
data_import_parameters = {"sep":"\s+", "header":None, "names": COLUMN_NAMES}

# Anomaly window for when errors occur
ANOMALY_HORIZON = 30

FD_IDS = ["FD001", "FD002", "FD003", "FD004"]

# Creating a list 
all_training_dfs = []

for fd_id in FD_IDS:

    RAW_FD_PATH = RAW_DATA_PATH
    RAW_DATA_FILE = f"train_{fd_id}.txt"

    raw_df = load_data(RAW_FD_PATH, RAW_DATA_FILE, **data_import_parameters)

    raw_df.columns = COLUMN_NAMES

    max_cycle = raw_df.groupby("unit")["cycle"].max().rename("max_cycle")
    logger.info(f"Max Cycle Dataframe Created: {raw_df.info()}")

    df = raw_df.merge(max_cycle, on="unit", how="left")
    logger.info(f"Raw Import Merged with Max Cycle: {df.info()}")

    df["RUL"] = df["max_cycle"] - df["cycle"]

    df = df.drop(columns=["max_cycle"])
    logger.info(f"RUL Calculcated and Added: {df.info()}")


    df["anomaly_flag"] = (df["RUL"] <= ANOMALY_HORIZON).astype(int)
    logger.info(f"Anomaly Flag Added: {df.info()}")

    df["dataset_name"] = "TURBOFAN"
    logger.info(f"Column Added: 'dataset_name': {df.info()}")

    df["fd_id"] = fd_id
    logger.info(f"Column Added: 'fd_id': {df.info()}")

    df["event_time"] = df["cycle"]
    logger.info(f"Column Added: 'event_time': {df.info()}")

    df = df.rename(columns={
                "unit": "machine_id",
                "cycle": "time_index",
                })
    logger.info(f"Columns Renamed: 'unit'>'machine_id' & 'cycle'>'time_index'  {df.info()}")

    core_columns = ["dataset_name", "fd_id", "machine_id", "time_index", "event_time"]
    logger.info(f"Core Columns Assigned and stored to list: {core_columns}")

    label_columns = ["RUL", "anomaly_flag"]
    logger.info(f"Label Columns Assigned and stored to list: {label_columns}")

    data_columns = list(df.columns)
    logger.info(f"Data Columns List created from existing columns in dataset: {data_columns}")

    for column in core_columns + label_columns: 
        if column in data_columns:
            data_columns.remove(column)

    logger.info(f"Data Columns List purged of core and label columns: {data_columns}")

    ordered_columns = core_columns + label_columns + data_columns
    logger.info(f"Column Order Set: {ordered_columns}")

    df_ordered = df[ordered_columns].copy()
    logger.info(f"Orderd Dataframe created: {df_ordered.info()}")

    all_training_dfs.append(df_ordered)
    logger.info(f"Orderd Dataframe appended to list of dataframes: {all_training_dfs}")


bronze_dfs = pd.concat(all_training_dfs, axis=0, ignore_index=True)
logger.info(f"All Dataframe concatenated into a single dataframe, vertically {bronze_dfs}")
# Out:
# INFO:__main__:Data File Loaded: None
# INFO:__main__:Max Cycle Dataframe Created: None
# INFO:__main__:Raw Import Merged with Max Cycle: None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20631 entries, 0 to 20630
# Data columns (total 26 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   unit          20631 non-null  int64
#  1   cycle         20631 non-null  int64
#  2   op_setting_1  20631 non-null  float64
#  3   op_setting_2  20631 non-null  float64
#  4   op_setting_3  20631 non-null  float64
#  5   s1            20631 non-null  float64
#  6   s2            20631 non-null  float64
#  7   s3            20631 non-null  float64
#  8   s4            20631 non-null  float64
#  9   s5            20631 non-null  float64
#  10  s6            20631 non-null  float64
#  11  s7            20631 non-null  float64
#  12  s8            20631 non-null  float64
#  13  s9            20631 non-null  float64
#  14  s10           20631 non-null  float64
#  15  s11           20631 non-null  float64
#  16  s12           20631 non-null  float64
#  17  s13           20631 non-null  float64
#  18  s14           20631 non-null  float64
#  19  s15           20631 non-null  float64
#  20  s16           20631 non-null  float64
#  21  s17           20631 non-null  int64
#  22  s18           20631 non-null  int64
#  23  s19           20631 non-null  float64
#  24  s20           20631 non-null  float64
#  25  s21           20631 non-null  float64
# dtypes: float64(22), int64(4)
# memory usage: 4.1 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20631 entries, 0 to 20630
# Data columns (total 26 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   unit          20631 non-null  int64
#  1   cycle         20631 non-null  int64
#  2   op_setting_1  20631 non-null  float64
#  3   op_setting_2  20631 non-null  float64
#  4   op_setting_3  20631 non-null  float64
#  5   s1            20631 non-null  float64
#  6   s2            20631 non-null  float64
#  7   s3            20631 non-null  float64
#  8   s4            20631 non-null  float64
#  9   s5            20631 non-null  float64
#  10  s6            20631 non-null  float64
#  11  s7            20631 non-null  float64
#  12  s8            20631 non-null  float64
#  13  s9            20631 non-null  float64
#  14  s10           20631 non-null  float64
#  15  s11           20631 non-null  float64
#  16  s12           20631 non-null  float64
#  17  s13           20631 non-null  float64
#  18  s14           20631 non-null  float64
#  19  s15           20631 non-null  float64
#  20  s16           20631 non-null  float64
#  21  s17           20631 non-null  int64
#  22  s18           20631 non-null  int64
#  23  s19           20631 non-null  float64
#  24  s20           20631 non-null  float64
#  25  s21           20631 non-null  float64
# dtypes: float64(22), int64(4)
# memory usage: 4.1 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20631 entries, 0 to 20630
# Data columns (total 27 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   unit          20631 non-null  int64
#  1   cycle         20631 non-null  int64
#  2   op_setting_1  20631 non-null  float64
#  3   op_setting_2  20631 non-null  float64
#  4   op_setting_3  20631 non-null  float64
#  5   s1            20631 non-null  float64
#  6   s2            20631 non-null  float64
#  7   s3            20631 non-null  float64
#  8   s4            20631 non-null  float64
#  9   s5            20631 non-null  float64
#  10  s6            20631 non-null  float64
#  11  s7            20631 non-null  float64
#  12  s8            20631 non-null  float64
#  13  s9            20631 non-null  float64
#  14  s10           20631 non-null  float64
#  15  s11           20631 non-null  float64
#  16  s12           20631 non-null  float64
#  17  s13           20631 non-null  float64
#  18  s14           20631 non-null  float64
#  19  s15           20631 non-null  float64
#  20  s16           20631 non-null  float64
#  21  s17           20631 non-null  int64
#  22  s18           20631 non-null  int64
#  23  s19           20631 non-null  float64
#  24  s20           20631 non-null  float64
#  25  s21           20631 non-null  float64
#  26  max_cycle     20631 non-null  int64
# dtypes: float64(22), int64(5)
# memory usage: 4.2 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20631 entries, 0 to 20630
# Data columns (total 27 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   unit          20631 non-null  int64
#  1   cycle         20631 non-null  int64
#  2   op_setting_1  20631 non-null  float64
#  3   op_setting_2  20631 non-null  float64
#  4   op_setting_3  20631 non-null  float64
#  5   s1            20631 non-null  float64
#  6   s2            20631 non-null  float64
#  7   s3            20631 non-null  float64
#  8   s4            20631 non-null  float64
#  9   s5            20631 non-null  float64
#  10  s6            20631 non-null  float64
#  11  s7            20631 non-null  float64
#  12  s8            20631 non-null  float64
#  13  s9            20631 non-null  float64
#  14  s10           20631 non-null  float64
#  15  s11           20631 non-null  float64
#  16  s12           20631 non-null  float64
#  17  s13           20631 non-null  float64
#  18  s14           20631 non-null  float64
#  19  s15           20631 non-null  float64
#  20  s16           20631 non-null  float64
#  21  s17           20631 non-null  int64
#  22  s18           20631 non-null  int64
#  23  s19           20631 non-null  float64
#  24  s20           20631 non-null  float64
#  25  s21           20631 non-null  float64
#  26  RUL           20631 non-null  int64
# dtypes: float64(22), int64(5)
# memory usage: 4.2 MB
# INFO:__main__:RUL Calculcated and Added: None
# INFO:__main__:Anomaly Flag Added: None
# INFO:__main__:Column Added: 'dataset_name': None
# INFO:__main__:Column Added: 'fd_id': None
# INFO:__main__:Column Added: 'event_time': None
# INFO:__main__:Columns Renamed: 'unit'>'machine_id' & 'cycle'>'time_index'  None
# INFO:__main__:Core Columns Assigned and stored to list: ['dataset_name', 'fd_id', 'machine_id', 'time_index', 'event_time']
# INFO:__main__:Label Columns Assigned and stored to list: ['RUL', 'anomaly_flag']
# INFO:__main__:Data Columns List created from existing columns in dataset: ['machine_id', 'time_index', 'op_setting_1', 'op_setting_2', 'op_setting_3', 's1', 's2', 's3', 's4', 's5', 's6', 's7', 's8', 's9', 's10', 's11', 's12', 's13', 's14', 's15', 's16', 's17', 's18', 's19', 's20', 's21', 'RUL', 'anomaly_flag', 'dataset_name', 'fd_id', 'event_time']
# INFO:__main__:Data Columns List purged of core and label columns: ['op_setting_1', 'op_setting_2', 'op_setting_3', 's1', 's2', 's3', 's4', 's5', 's6', 's7', 's8', 's9', 's10', 's11', 's12', 's13', 's14', 's15', 's16', 's17', 's18', 's19', 's20', 's21']
# INFO:__main__:Column Order Set: ['dataset_name', 'fd_id', 'machine_id', 'time_index', 'event_time', 'RUL', 'anomaly_flag', 'op_setting_1', 'op_setting_2', 'op_setting_3', 's1', 's2', 's3', 's4', 's5', 's6', 's7', 's8', 's9', 's10', 's11', 's12', 's13', 's14', 's15', 's16', 's17', 's18', 's19', 's20', 's21']
# INFO:__main__:Orderd Dataframe created: None
# INFO:__main__:Orderd Dataframe appended to list of dataframes: [      dataset_name  fd_id  machine_id  time_index  event_time  RUL  anomaly_flag  op_setting_1  op_setting_2  op_setting_3      s1      s2       s3       s4     s5     s6      s7       s8       s9  \
# 0         TURBOFAN  FD001           1           1           1  191             0       -0.0007       -0.0004         100.0  518.67  641.82  1589.70  1400.60  14.62  21.61  554.36  2388.06  9046.19
# 1         TURBOFAN  FD001           1           2           2  190             0        0.0019       -0.0003         100.0  518.67  642.15  1591.82  1403.14  14.62  21.61  553.75  2388.04  9044.07
# 2         TURBOFAN  FD001           1           3           3  189             0       -0.0043        0.0003         100.0  518.67  642.35  1587.99  1404.20  14.62  21.61  554.26  2388.08  9052.94
# 3         TURBOFAN  FD001           1           4           4  188             0        0.0007        0.0000         100.0  518.67  642.35  1582.79  1401.87  14.62  21.61  554.45  2388.11  9049.48
# 4         TURBOFAN  FD001           1           5           5  187             0       -0.0019       -0.0002         100.0  518.67  642.37  1582.85  1406.22  14.62  21.61  554.00  2388.06  9055.15
# ...            ...    ...         ...         ...         ...  ...           ...           ...           ...           ...     ...     ...      ...      ...    ...    ...     ...      ...      ...
# 20626     TURBOFAN  FD001         100         196         196    4             1       -0.0004       -0.0003         100.0  518.67  643.49  1597.98  1428.63  14.62  21.61  551.43  2388.19  9065.52
# 20627     TURBOFAN  FD001         100         197         197    3             1       -0.0016       -0.0005         100.0  518.67  643.54  1604.50  1433.58  14.62  21.61  550.86  2388.23  9065.11
# 20628     TURBOFAN  FD001         100         198         198    2             1        0.0004        0.0000         100.0  518.67  643.42  1602.46  1428.18  14.62  21.61  550.94  2388.24  9065.90
# 20629     TURBOFAN  FD001         100         199         199    1             1       -0.0011        0.0003         100.0  518.67  643.23  1605.26  1426.53  14.62  21.61  550.68  2388.25  9073.72
# 20630     TURBOFAN  FD001         100         200         200    0             1       -0.0032       -0.0005         100.0  518.67  643.85  1600.38  1432.14  14.62  21.61  550.79  2388.26  9061.48
#
#        s10    s11     s12      s13      s14     s15   s16  s17   s18    s19    s20      s21
# 0      1.3  47.47  521.66  2388.02  8138.62  8.4195  0.03  392  2388  100.0  39.06  23.4190
# 1      1.3  47.49  522.28  2388.07  8131.49  8.4318  0.03  392  2388  100.0  39.00  23.4236
# 2      1.3  47.27  522.42  2388.03  8133.23  8.4178  0.03  390  2388  100.0  38.95  23.3442
# 3      1.3  47.13  522.86  2388.08  8133.83  8.3682  0.03  392  2388  100.0  38.88  23.3739
# 4      1.3  47.28  522.19  2388.04  8133.80  8.4294  0.03  393  2388  100.0  38.90  23.4044
# ...    ...    ...     ...      ...      ...     ...   ...  ...   ...    ...    ...      ...
# 20626  1.3  48.07  519.49  2388.26  8137.60  8.4956  0.03  397  2388  100.0  38.49  22.9735
# 20627  1.3  48.04  519.68  2388.22  8136.50  8.5139  0.03  395  2388  100.0  38.30  23.1594
# 20628  1.3  48.09  520.01  2388.24  8141.05  8.5646  0.03  398  2388  100.0  38.44  22.9333
# 20629  1.3  48.39  519.67  2388.23  8139.29  8.5389  0.03  395  2388  100.0  38.29  23.0640
# 20630  1.3  48.20  519.30  2388.26  8137.33  8.5036  0.03  396  2388  100.0  38.37  23.0522
#
# [20631 rows x 31 columns]]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20631 entries, 0 to 20630
# Data columns (total 28 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   unit          20631 non-null  int64
#  1   cycle         20631 non-null  int64
#  2   op_setting_1  20631 non-null  float64
#  3   op_setting_2  20631 non-null  float64
#  4   op_setting_3  20631 non-null  float64
#  5   s1            20631 non-null  float64
#  6   s2            20631 non-null  float64
#  7   s3            20631 non-null  float64
#  8   s4            20631 non-null  float64
#  9   s5            20631 non-null  float64
#  10  s6            20631 non-null  float64
#  11  s7            20631 non-null  float64
#  12  s8            20631 non-null  float64
#  13  s9            20631 non-null  float64
#  14  s10           20631 non-null  float64
#  15  s11           20631 non-null  float64
#  16  s12           20631 non-null  float64
#  17  s13           20631 non-null  float64
#  18  s14           20631 non-null  float64
#  19  s15           20631 non-null  float64
#  20  s16           20631 non-null  float64
#  21  s17           20631 non-null  int64
#  22  s18           20631 non-null  int64
#  23  s19           20631 non-null  float64
#  24  s20           20631 non-null  float64
#  25  s21           20631 non-null  float64
#  26  RUL           20631 non-null  int64
#  27  anomaly_flag  20631 non-null  int64
# dtypes: float64(22), int64(6)
# memory usage: 4.4 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20631 entries, 0 to 20630
# Data columns (total 29 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   unit          20631 non-null  int64
#  1   cycle         20631 non-null  int64
#  2   op_setting_1  20631 non-null  float64
#  3   op_setting_2  20631 non-null  float64
#  4   op_setting_3  20631 non-null  float64
#  5   s1            20631 non-null  float64
#  6   s2            20631 non-null  float64
#  7   s3            20631 non-null  float64
#  8   s4            20631 non-null  float64
#  9   s5            20631 non-null  float64
#  10  s6            20631 non-null  float64
#  11  s7            20631 non-null  float64
#  12  s8            20631 non-null  float64
#  13  s9            20631 non-null  float64
#  14  s10           20631 non-null  float64
#  15  s11           20631 non-null  float64
#  16  s12           20631 non-null  float64
#  17  s13           20631 non-null  float64
#  18  s14           20631 non-null  float64
#  19  s15           20631 non-null  float64
#  20  s16           20631 non-null  float64
#  21  s17           20631 non-null  int64
#  22  s18           20631 non-null  int64
#  23  s19           20631 non-null  float64
#  24  s20           20631 non-null  float64
#  25  s21           20631 non-null  float64
#  26  RUL           20631 non-null  int64
#  27  anomaly_flag  20631 non-null  int64
#  28  dataset_name  20631 non-null  object
# dtypes: float64(22), int64(6), object(1)
# memory usage: 4.6+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20631 entries, 0 to 20630
# Data columns (total 30 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   unit          20631 non-null  int64
#  1   cycle         20631 non-null  int64
#  2   op_setting_1  20631 non-null  float64
#  3   op_setting_2  20631 non-null  float64
#  4   op_setting_3  20631 non-null  float64
#  5   s1            20631 non-null  float64
#  6   s2            20631 non-null  float64
#  7   s3            20631 non-null  float64
#  8   s4            20631 non-null  float64
#  9   s5            20631 non-null  float64
#  10  s6            20631 non-null  float64
#  11  s7            20631 non-null  float64
#  12  s8            20631 non-null  float64
#  13  s9            20631 non-null  float64
#  14  s10           20631 non-null  float64
#  15  s11           20631 non-null  float64
#  16  s12           20631 non-null  float64
#  17  s13           20631 non-null  float64
#  18  s14           20631 non-null  float64
#  19  s15           20631 non-null  float64
#  20  s16           20631 non-null  float64
#  21  s17           20631 non-null  int64
#  22  s18           20631 non-null  int64
#  23  s19           20631 non-null  float64
#  24  s20           20631 non-null  float64
#  25  s21           20631 non-null  float64
#  26  RUL           20631 non-null  int64
#  27  anomaly_flag  20631 non-null  int64
#  28  dataset_name  20631 non-null  object
#  29  fd_id         20631 non-null  object
# dtypes: float64(22), int64(6), object(2)
# memory usage: 4.7+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20631 entries, 0 to 20630
# Data columns (total 31 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   unit          20631 non-null  int64
#  1   cycle         20631 non-null  int64
#  2   op_setting_1  20631 non-null  float64
#  3   op_setting_2  20631 non-null  float64
#  4   op_setting_3  20631 non-null  float64
#  5   s1            20631 non-null  float64
#  6   s2            20631 non-null  float64
#  7   s3            20631 non-null  float64
#  8   s4            20631 non-null  float64
#  9   s5            20631 non-null  float64
#  10  s6            20631 non-null  float64
#  11  s7            20631 non-null  float64
#  12  s8            20631 non-null  float64
#  13  s9            20631 non-null  float64
#  14  s10           20631 non-null  float64
#  15  s11           20631 non-null  float64
#  16  s12           20631 non-null  float64
#  17  s13           20631 non-null  float64
#  18  s14           20631 non-null  float64
#  19  s15           20631 non-null  float64
#  20  s16           20631 non-null  float64
#  21  s17           20631 non-null  int64
#  22  s18           20631 non-null  int64
#  23  s19           20631 non-null  float64
#  24  s20           20631 non-null  float64
#  25  s21           20631 non-null  float64
#  26  RUL           20631 non-null  int64
#  27  anomaly_flag  20631 non-null  int64
#  28  dataset_name  20631 non-null  object
#  29  fd_id         20631 non-null  object
#  30  event_time    20631 non-null  int64
# dtypes: float64(22), int64(7), object(2)
# memory usage: 4.9+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20631 entries, 0 to 20630
# Data columns (total 31 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   machine_id    20631 non-null  int64
#  1   time_index    20631 non-null  int64
#  2   op_setting_1  20631 non-null  float64
#  3   op_setting_2  20631 non-null  float64
#  4   op_setting_3  20631 non-null  float64
#  5   s1            20631 non-null  float64
#  6   s2            20631 non-null  float64
#  7   s3            20631 non-null  float64
#  8   s4            20631 non-null  float64
#  9   s5            20631 non-null  float64
#  10  s6            20631 non-null  float64
#  11  s7            20631 non-null  float64
#  12  s8            20631 non-null  float64
#  13  s9            20631 non-null  float64
#  14  s10           20631 non-null  float64
#  15  s11           20631 non-null  float64
#  16  s12           20631 non-null  float64
#  17  s13           20631 non-null  float64
#  18  s14           20631 non-null  float64
#  19  s15           20631 non-null  float64
#  20  s16           20631 non-null  float64
#  21  s17           20631 non-null  int64
#  22  s18           20631 non-null  int64
#  23  s19           20631 non-null  float64
#  24  s20           20631 non-null  float64
#  25  s21           20631 non-null  float64
#  26  RUL           20631 non-null  int64
#  27  anomaly_flag  20631 non-null  int64
#  28  dataset_name  20631 non-null  object
#  29  fd_id         20631 non-null  object
#  30  event_time    20631 non-null  int64
# dtypes: float64(22), int64(7), object(2)
# memory usage: 4.9+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20631 entries, 0 to 20630
# Data columns (total 31 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   dataset_name  20631 non-null  object
#  1   fd_id         20631 non-null  object
#  2   machine_id    20631 non-null  int64
#  3   time_index    20631 non-null  int64
#  4   event_time    20631 non-null  int64
#  5   RUL           20631 non-null  int64
#  6   anomaly_flag  20631 non-null  int64
#  7   op_setting_1  20631 non-null  float64
#  8   op_setting_2  20631 non-null  float64
#  9   op_setting_3  20631 non-null  float64
#  10  s1            20631 non-null  float64
#  11  s2            20631 non-null  float64
#  12  s3            20631 non-null  float64
#  13  s4            20631 non-null  float64
#  14  s5            20631 non-null  float64
#  15  s6            20631 non-null  float64
#  16  s7            20631 non-null  float64
#  17  s8            20631 non-null  float64
#  18  s9            20631 non-null  float64
#  19  s10           20631 non-null  float64
#  20  s11           20631 non-null  float64
#  21  s12           20631 non-null  float64
#  22  s13           20631 non-null  float64
#  23  s14           20631 non-null  float64
#  24  s15           20631 non-null  float64
#  25  s16           20631 non-null  float64
#  26  s17           20631 non-null  int64
#  27  s18           20631 non-null  int64
#  28  s19           20631 non-null  float64
#  29  s20           20631 non-null  float64
#  30  s21           20631 non-null  float64
# dtypes: float64(22), int64(7), object(2)
# memory usage: 4.9+ MB
# INFO:__main__:Data File Loaded: None
# INFO:__main__:Max Cycle Dataframe Created: None
# INFO:__main__:Raw Import Merged with Max Cycle: None
# INFO:__main__:RUL Calculcated and Added: None
# INFO:__main__:Anomaly Flag Added: None
# INFO:__main__:Column Added: 'dataset_name': None
# INFO:__main__:Column Added: 'fd_id': None
# INFO:__main__:Column Added: 'event_time': None
# INFO:__main__:Columns Renamed: 'unit'>'machine_id' & 'cycle'>'time_index'  None
# INFO:__main__:Core Columns Assigned and stored to list: ['dataset_name', 'fd_id', 'machine_id', 'time_index', 'event_time']
# INFO:__main__:Label Columns Assigned and stored to list: ['RUL', 'anomaly_flag']
# INFO:__main__:Data Columns List created from existing columns in dataset: ['machine_id', 'time_index', 'op_setting_1', 'op_setting_2', 'op_setting_3', 's1', 's2', 's3', 's4', 's5', 's6', 's7', 's8', 's9', 's10', 's11', 's12', 's13', 's14', 's15', 's16', 's17', 's18', 's19', 's20', 's21', 'RUL', 'anomaly_flag', 'dataset_name', 'fd_id', 'event_time']
# INFO:__main__:Data Columns List purged of core and label columns: ['op_setting_1', 'op_setting_2', 'op_setting_3', 's1', 's2', 's3', 's4', 's5', 's6', 's7', 's8', 's9', 's10', 's11', 's12', 's13', 's14', 's15', 's16', 's17', 's18', 's19', 's20', 's21']
# INFO:__main__:Column Order Set: ['dataset_name', 'fd_id', 'machine_id', 'time_index', 'event_time', 'RUL', 'anomaly_flag', 'op_setting_1', 'op_setting_2', 'op_setting_3', 's1', 's2', 's3', 's4', 's5', 's6', 's7', 's8', 's9', 's10', 's11', 's12', 's13', 's14', 's15', 's16', 's17', 's18', 's19', 's20', 's21']
# INFO:__main__:Orderd Dataframe created: None
# INFO:__main__:Orderd Dataframe appended to list of dataframes: [      dataset_name  fd_id  machine_id  time_index  event_time  RUL  anomaly_flag  op_setting_1  op_setting_2  op_setting_3      s1      s2       s3       s4     s5     s6      s7       s8       s9  \
# 0         TURBOFAN  FD001           1           1           1  191             0       -0.0007       -0.0004         100.0  518.67  641.82  1589.70  1400.60  14.62  21.61  554.36  2388.06  9046.19
# 1         TURBOFAN  FD001           1           2           2  190             0        0.0019       -0.0003         100.0  518.67  642.15  1591.82  1403.14  14.62  21.61  553.75  2388.04  9044.07
# 2         TURBOFAN  FD001           1           3           3  189             0       -0.0043        0.0003         100.0  518.67  642.35  1587.99  1404.20  14.62  21.61  554.26  2388.08  9052.94
# 3         TURBOFAN  FD001           1           4           4  188             0        0.0007        0.0000         100.0  518.67  642.35  1582.79  1401.87  14.62  21.61  554.45  2388.11  9049.48
# 4         TURBOFAN  FD001           1           5           5  187             0       -0.0019       -0.0002         100.0  518.67  642.37  1582.85  1406.22  14.62  21.61  554.00  2388.06  9055.15
# ...            ...    ...         ...         ...         ...  ...           ...           ...           ...           ...     ...     ...      ...      ...    ...    ...     ...      ...      ...
# 20626     TURBOFAN  FD001         100         196         196    4             1       -0.0004       -0.0003         100.0  518.67  643.49  1597.98  1428.63  14.62  21.61  551.43  2388.19  9065.52
# 20627     TURBOFAN  FD001         100         197         197    3             1       -0.0016       -0.0005         100.0  518.67  643.54  1604.50  1433.58  14.62  21.61  550.86  2388.23  9065.11
# 20628     TURBOFAN  FD001         100         198         198    2             1        0.0004        0.0000         100.0  518.67  643.42  1602.46  1428.18  14.62  21.61  550.94  2388.24  9065.90
# 20629     TURBOFAN  FD001         100         199         199    1             1       -0.0011        0.0003         100.0  518.67  643.23  1605.26  1426.53  14.62  21.61  550.68  2388.25  9073.72
# 20630     TURBOFAN  FD001         100         200         200    0             1       -0.0032       -0.0005         100.0  518.67  643.85  1600.38  1432.14  14.62  21.61  550.79  2388.26  9061.48
#
#        s10    s11     s12      s13      s14     s15   s16  s17   s18    s19    s20      s21
# 0      1.3  47.47  521.66  2388.02  8138.62  8.4195  0.03  392  2388  100.0  39.06  23.4190
# 1      1.3  47.49  522.28  2388.07  8131.49  8.4318  0.03  392  2388  100.0  39.00  23.4236
# 2      1.3  47.27  522.42  2388.03  8133.23  8.4178  0.03  390  2388  100.0  38.95  23.3442
# 3      1.3  47.13  522.86  2388.08  8133.83  8.3682  0.03  392  2388  100.0  38.88  23.3739
# 4      1.3  47.28  522.19  2388.04  8133.80  8.4294  0.03  393  2388  100.0  38.90  23.4044
# ...    ...    ...     ...      ...      ...     ...   ...  ...   ...    ...    ...      ...
# 20626  1.3  48.07  519.49  2388.26  8137.60  8.4956  0.03  397  2388  100.0  38.49  22.9735
# 20627  1.3  48.04  519.68  2388.22  8136.50  8.5139  0.03  395  2388  100.0  38.30  23.1594
# 20628  1.3  48.09  520.01  2388.24  8141.05  8.5646  0.03  398  2388  100.0  38.44  22.9333
# 20629  1.3  48.39  519.67  2388.23  8139.29  8.5389  0.03  395  2388  100.0  38.29  23.0640
# 20630  1.3  48.20  519.30  2388.26  8137.33  8.5036  0.03  396  2388  100.0  38.37  23.0522
#
# [20631 rows x 31 columns],       dataset_name  fd_id  machine_id  time_index  event_time  RUL  anomaly_flag  op_setting_1  op_setting_2  op_setting_3      s1      s2       s3       s4     s5     s6      s7       s8       s9  \
# 0         TURBOFAN  FD002           1           1           1  148             0       34.9983        0.8400         100.0  449.44  555.32  1358.61  1137.23   5.48   8.00  194.64  2222.65  8341.91
# 1         TURBOFAN  FD002           1           2           2  147             0       41.9982        0.8408         100.0  445.00  549.90  1353.22  1125.78   3.91   5.71  138.51  2211.57  8303.96
# 2         TURBOFAN  FD002           1           3           3  146             0       24.9988        0.6218          60.0  462.54  537.31  1256.76  1047.45   7.05   9.02  175.71  1915.11  8001.42
# 3         TURBOFAN  FD002           1           4           4  145             0       42.0077        0.8416         100.0  445.00  549.51  1354.03  1126.38   3.91   5.71  138.46  2211.58  8303.96
# 4         TURBOFAN  FD002           1           5           5  144             0       25.0005        0.6203          60.0  462.54  537.07  1257.71  1047.93   7.05   9.03  175.05  1915.10  7993.23
# ...            ...    ...         ...         ...         ...  ...           ...           ...           ...           ...     ...     ...      ...      ...    ...    ...     ...      ...      ...
# 53754     TURBOFAN  FD002         260         312         312    4             1       20.0037        0.7000         100.0  491.19  608.79  1495.60  1269.51   9.35  13.66  334.00  2324.92  8852.27
# 53755     TURBOFAN  FD002         260         313         313    3             1       10.0022        0.2510         100.0  489.05  605.81  1514.32  1324.12  10.52  15.50  392.46  2319.17  8915.86
# 53756     TURBOFAN  FD002         260         314         314    2             1       25.0041        0.6200          60.0  462.54  537.48  1276.24  1057.92   7.05   9.04  175.11  1917.37  8114.33
# 53757     TURBOFAN  FD002         260         315         315    1             1       25.0033        0.6220          60.0  462.54  537.84  1272.95  1066.30   7.05   9.04  174.81  1917.36  8112.63
# 53758     TURBOFAN  FD002         260         316         316    0             1       35.0036        0.8400         100.0  449.44  556.64  1374.61  1145.52   5.48   8.01  194.33  2225.12  8478.44
#
#         s10    s11     s12      s13      s14      s15   s16  s17   s18     s19    s20      s21
# 0      1.02  42.02  183.06  2387.72  8048.56   9.3461  0.02  334  2223  100.00  14.73   8.8071
# 1      1.02  42.20  130.42  2387.66  8072.30   9.3774  0.02  330  2212  100.00  10.41   6.2665
# 2      0.94  36.69  164.22  2028.03  7864.87  10.8941  0.02  309  1915   84.93  14.08   8.6723
# 3      1.02  41.96  130.72  2387.61  8068.66   9.3528  0.02  329  2212  100.00  10.59   6.4701
# 4      0.94  36.89  164.31  2028.00  7861.23  10.8963  0.02  309  1915   84.93  14.13   8.5286
# ...     ...    ...     ...      ...      ...      ...   ...  ...   ...     ...    ...      ...
# 53754  1.07  44.72  314.05  2389.02  8169.64   9.3035  0.03  369  2324  100.00  24.36  14.5189
# 53755  1.26  46.08  371.22  2388.42  8245.36   8.7586  0.03  374  2319  100.00  28.10  16.9454
# 53756  0.94  37.14  163.74  2030.33  7971.25  11.0657  0.02  310  1915   84.93  14.19   8.5503
# 53757  0.94  37.32  164.37  2030.35  7972.47  11.0537  0.02  311  1915   84.93  14.05   8.3729
# 53758  1.02  42.50  183.09  2390.38  8185.35   9.3998  0.02  338  2223  100.00  14.75   8.8446
#
# [53759 rows x 31 columns]]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53759 entries, 0 to 53758
# Data columns (total 26 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   unit          53759 non-null  int64
#  1   cycle         53759 non-null  int64
#  2   op_setting_1  53759 non-null  float64
#  3   op_setting_2  53759 non-null  float64
#  4   op_setting_3  53759 non-null  float64
#  5   s1            53759 non-null  float64
#  6   s2            53759 non-null  float64
#  7   s3            53759 non-null  float64
#  8   s4            53759 non-null  float64
#  9   s5            53759 non-null  float64
#  10  s6            53759 non-null  float64
#  11  s7            53759 non-null  float64
#  12  s8            53759 non-null  float64
#  13  s9            53759 non-null  float64
#  14  s10           53759 non-null  float64
#  15  s11           53759 non-null  float64
#  16  s12           53759 non-null  float64
#  17  s13           53759 non-null  float64
#  18  s14           53759 non-null  float64
#  19  s15           53759 non-null  float64
#  20  s16           53759 non-null  float64
#  21  s17           53759 non-null  int64
#  22  s18           53759 non-null  int64
#  23  s19           53759 non-null  float64
#  24  s20           53759 non-null  float64
#  25  s21           53759 non-null  float64
# dtypes: float64(22), int64(4)
# memory usage: 10.7 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53759 entries, 0 to 53758
# Data columns (total 26 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   unit          53759 non-null  int64
#  1   cycle         53759 non-null  int64
#  2   op_setting_1  53759 non-null  float64
#  3   op_setting_2  53759 non-null  float64
#  4   op_setting_3  53759 non-null  float64
#  5   s1            53759 non-null  float64
#  6   s2            53759 non-null  float64
#  7   s3            53759 non-null  float64
#  8   s4            53759 non-null  float64
#  9   s5            53759 non-null  float64
#  10  s6            53759 non-null  float64
#  11  s7            53759 non-null  float64
#  12  s8            53759 non-null  float64
#  13  s9            53759 non-null  float64
#  14  s10           53759 non-null  float64
#  15  s11           53759 non-null  float64
#  16  s12           53759 non-null  float64
#  17  s13           53759 non-null  float64
#  18  s14           53759 non-null  float64
#  19  s15           53759 non-null  float64
#  20  s16           53759 non-null  float64
#  21  s17           53759 non-null  int64
#  22  s18           53759 non-null  int64
#  23  s19           53759 non-null  float64
#  24  s20           53759 non-null  float64
#  25  s21           53759 non-null  float64
# dtypes: float64(22), int64(4)
# memory usage: 10.7 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53759 entries, 0 to 53758
# Data columns (total 27 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   unit          53759 non-null  int64
#  1   cycle         53759 non-null  int64
#  2   op_setting_1  53759 non-null  float64
#  3   op_setting_2  53759 non-null  float64
#  4   op_setting_3  53759 non-null  float64
#  5   s1            53759 non-null  float64
#  6   s2            53759 non-null  float64
#  7   s3            53759 non-null  float64
#  8   s4            53759 non-null  float64
#  9   s5            53759 non-null  float64
#  10  s6            53759 non-null  float64
#  11  s7            53759 non-null  float64
#  12  s8            53759 non-null  float64
#  13  s9            53759 non-null  float64
#  14  s10           53759 non-null  float64
#  15  s11           53759 non-null  float64
#  16  s12           53759 non-null  float64
#  17  s13           53759 non-null  float64
#  18  s14           53759 non-null  float64
#  19  s15           53759 non-null  float64
#  20  s16           53759 non-null  float64
#  21  s17           53759 non-null  int64
#  22  s18           53759 non-null  int64
#  23  s19           53759 non-null  float64
#  24  s20           53759 non-null  float64
#  25  s21           53759 non-null  float64
#  26  max_cycle     53759 non-null  int64
# dtypes: float64(22), int64(5)
# memory usage: 11.1 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53759 entries, 0 to 53758
# Data columns (total 27 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   unit          53759 non-null  int64
#  1   cycle         53759 non-null  int64
#  2   op_setting_1  53759 non-null  float64
#  3   op_setting_2  53759 non-null  float64
#  4   op_setting_3  53759 non-null  float64
#  5   s1            53759 non-null  float64
#  6   s2            53759 non-null  float64
#  7   s3            53759 non-null  float64
#  8   s4            53759 non-null  float64
#  9   s5            53759 non-null  float64
#  10  s6            53759 non-null  float64
#  11  s7            53759 non-null  float64
#  12  s8            53759 non-null  float64
#  13  s9            53759 non-null  float64
#  14  s10           53759 non-null  float64
#  15  s11           53759 non-null  float64
#  16  s12           53759 non-null  float64
#  17  s13           53759 non-null  float64
#  18  s14           53759 non-null  float64
#  19  s15           53759 non-null  float64
#  20  s16           53759 non-null  float64
#  21  s17           53759 non-null  int64
#  22  s18           53759 non-null  int64
#  23  s19           53759 non-null  float64
#  24  s20           53759 non-null  float64
#  25  s21           53759 non-null  float64
#  26  RUL           53759 non-null  int64
# dtypes: float64(22), int64(5)
# memory usage: 11.1 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53759 entries, 0 to 53758
# Data columns (total 28 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   unit          53759 non-null  int64
#  1   cycle         53759 non-null  int64
#  2   op_setting_1  53759 non-null  float64
#  3   op_setting_2  53759 non-null  float64
#  4   op_setting_3  53759 non-null  float64
#  5   s1            53759 non-null  float64
#  6   s2            53759 non-null  float64
#  7   s3            53759 non-null  float64
#  8   s4            53759 non-null  float64
#  9   s5            53759 non-null  float64
#  10  s6            53759 non-null  float64
#  11  s7            53759 non-null  float64
#  12  s8            53759 non-null  float64
#  13  s9            53759 non-null  float64
#  14  s10           53759 non-null  float64
#  15  s11           53759 non-null  float64
#  16  s12           53759 non-null  float64
#  17  s13           53759 non-null  float64
#  18  s14           53759 non-null  float64
#  19  s15           53759 non-null  float64
#  20  s16           53759 non-null  float64
#  21  s17           53759 non-null  int64
#  22  s18           53759 non-null  int64
#  23  s19           53759 non-null  float64
#  24  s20           53759 non-null  float64
#  25  s21           53759 non-null  float64
#  26  RUL           53759 non-null  int64
#  27  anomaly_flag  53759 non-null  int64
# dtypes: float64(22), int64(6)
# memory usage: 11.5 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53759 entries, 0 to 53758
# Data columns (total 29 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   unit          53759 non-null  int64
#  1   cycle         53759 non-null  int64
#  2   op_setting_1  53759 non-null  float64
#  3   op_setting_2  53759 non-null  float64
#  4   op_setting_3  53759 non-null  float64
#  5   s1            53759 non-null  float64
#  6   s2            53759 non-null  float64
#  7   s3            53759 non-null  float64
#  8   s4            53759 non-null  float64
#  9   s5            53759 non-null  float64
#  10  s6            53759 non-null  float64
#  11  s7            53759 non-null  float64
#  12  s8            53759 non-null  float64
#  13  s9            53759 non-null  float64
#  14  s10           53759 non-null  float64
#  15  s11           53759 non-null  float64
#  16  s12           53759 non-null  float64
#  17  s13           53759 non-null  float64
#  18  s14           53759 non-null  float64
#  19  s15           53759 non-null  float64
#  20  s16           53759 non-null  float64
#  21  s17           53759 non-null  int64
#  22  s18           53759 non-null  int64
#  23  s19           53759 non-null  float64
#  24  s20           53759 non-null  float64
#  25  s21           53759 non-null  float64
#  26  RUL           53759 non-null  int64
#  27  anomaly_flag  53759 non-null  int64
#  28  dataset_name  53759 non-null  object
# dtypes: float64(22), int64(6), object(1)
# memory usage: 11.9+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53759 entries, 0 to 53758
# Data columns (total 30 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   unit          53759 non-null  int64
#  1   cycle         53759 non-null  int64
#  2   op_setting_1  53759 non-null  float64
#  3   op_setting_2  53759 non-null  float64
#  4   op_setting_3  53759 non-null  float64
#  5   s1            53759 non-null  float64
#  6   s2            53759 non-null  float64
#  7   s3            53759 non-null  float64
#  8   s4            53759 non-null  float64
#  9   s5            53759 non-null  float64
#  10  s6            53759 non-null  float64
#  11  s7            53759 non-null  float64
#  12  s8            53759 non-null  float64
#  13  s9            53759 non-null  float64
#  14  s10           53759 non-null  float64
#  15  s11           53759 non-null  float64
#  16  s12           53759 non-null  float64
#  17  s13           53759 non-null  float64
#  18  s14           53759 non-null  float64
#  19  s15           53759 non-null  float64
#  20  s16           53759 non-null  float64
#  21  s17           53759 non-null  int64
#  22  s18           53759 non-null  int64
#  23  s19           53759 non-null  float64
#  24  s20           53759 non-null  float64
#  25  s21           53759 non-null  float64
#  26  RUL           53759 non-null  int64
#  27  anomaly_flag  53759 non-null  int64
#  28  dataset_name  53759 non-null  object
#  29  fd_id         53759 non-null  object
# dtypes: float64(22), int64(6), object(2)
# memory usage: 12.3+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53759 entries, 0 to 53758
# Data columns (total 31 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   unit          53759 non-null  int64
#  1   cycle         53759 non-null  int64
#  2   op_setting_1  53759 non-null  float64
#  3   op_setting_2  53759 non-null  float64
#  4   op_setting_3  53759 non-null  float64
#  5   s1            53759 non-null  float64
#  6   s2            53759 non-null  float64
#  7   s3            53759 non-null  float64
#  8   s4            53759 non-null  float64
#  9   s5            53759 non-null  float64
#  10  s6            53759 non-null  float64
#  11  s7            53759 non-null  float64
#  12  s8            53759 non-null  float64
#  13  s9            53759 non-null  float64
#  14  s10           53759 non-null  float64
#  15  s11           53759 non-null  float64
#  16  s12           53759 non-null  float64
#  17  s13           53759 non-null  float64
#  18  s14           53759 non-null  float64
#  19  s15           53759 non-null  float64
#  20  s16           53759 non-null  float64
#  21  s17           53759 non-null  int64
#  22  s18           53759 non-null  int64
#  23  s19           53759 non-null  float64
#  24  s20           53759 non-null  float64
#  25  s21           53759 non-null  float64
#  26  RUL           53759 non-null  int64
#  27  anomaly_flag  53759 non-null  int64
#  28  dataset_name  53759 non-null  object
#  29  fd_id         53759 non-null  object
#  30  event_time    53759 non-null  int64
# dtypes: float64(22), int64(7), object(2)
# memory usage: 12.7+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53759 entries, 0 to 53758
# Data columns (total 31 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   machine_id    53759 non-null  int64
#  1   time_index    53759 non-null  int64
#  2   op_setting_1  53759 non-null  float64
#  3   op_setting_2  53759 non-null  float64
#  4   op_setting_3  53759 non-null  float64
#  5   s1            53759 non-null  float64
#  6   s2            53759 non-null  float64
#  7   s3            53759 non-null  float64
#  8   s4            53759 non-null  float64
#  9   s5            53759 non-null  float64
#  10  s6            53759 non-null  float64
#  11  s7            53759 non-null  float64
#  12  s8            53759 non-null  float64
#  13  s9            53759 non-null  float64
#  14  s10           53759 non-null  float64
#  15  s11           53759 non-null  float64
#  16  s12           53759 non-null  float64
#  17  s13           53759 non-null  float64
#  18  s14           53759 non-null  float64
#  19  s15           53759 non-null  float64
#  20  s16           53759 non-null  float64
#  21  s17           53759 non-null  int64
#  22  s18           53759 non-null  int64
#  23  s19           53759 non-null  float64
#  24  s20           53759 non-null  float64
#  25  s21           53759 non-null  float64
#  26  RUL           53759 non-null  int64
#  27  anomaly_flag  53759 non-null  int64
#  28  dataset_name  53759 non-null  object
#  29  fd_id         53759 non-null  object
#  30  event_time    53759 non-null  int64
# dtypes: float64(22), int64(7), object(2)
# memory usage: 12.7+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53759 entries, 0 to 53758
# Data columns (total 31 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   dataset_name  53759 non-null  object
#  1   fd_id         53759 non-null  object
#  2   machine_id    53759 non-null  int64
#  3   time_index    53759 non-null  int64
#  4   event_time    53759 non-null  int64
#  5   RUL           53759 non-null  int64
#  6   anomaly_flag  53759 non-null  int64
#  7   op_setting_1  53759 non-null  float64
#  8   op_setting_2  53759 non-null  float64
#  9   op_setting_3  53759 non-null  float64
#  10  s1            53759 non-null  float64
#  11  s2            53759 non-null  float64
#  12  s3            53759 non-null  float64
#  13  s4            53759 non-null  float64
#  14  s5            53759 non-null  float64
#  15  s6            53759 non-null  float64
#  16  s7            53759 non-null  float64
#  17  s8            53759 non-null  float64
#  18  s9            53759 non-null  float64
#  19  s10           53759 non-null  float64
#  20  s11           53759 non-null  float64
#  21  s12           53759 non-null  float64
#  22  s13           53759 non-null  float64
#  23  s14           53759 non-null  float64
#  24  s15           53759 non-null  float64
#  25  s16           53759 non-null  float64
#  26  s17           53759 non-null  int64
#  27  s18           53759 non-null  int64
#  28  s19           53759 non-null  float64
#  29  s20           53759 non-null  float64
#  30  s21           53759 non-null  float64
# dtypes: float64(22), int64(7), object(2)
# memory usage: 12.7+ MB
# INFO:__main__:Data File Loaded: None
# INFO:__main__:Max Cycle Dataframe Created: None
# INFO:__main__:Raw Import Merged with Max Cycle: None
# INFO:__main__:RUL Calculcated and Added: None
# INFO:__main__:Anomaly Flag Added: None
# INFO:__main__:Column Added: 'dataset_name': None
# INFO:__main__:Column Added: 'fd_id': None
# INFO:__main__:Column Added: 'event_time': None
# INFO:__main__:Columns Renamed: 'unit'>'machine_id' & 'cycle'>'time_index'  None
# INFO:__main__:Core Columns Assigned and stored to list: ['dataset_name', 'fd_id', 'machine_id', 'time_index', 'event_time']
# INFO:__main__:Label Columns Assigned and stored to list: ['RUL', 'anomaly_flag']
# INFO:__main__:Data Columns List created from existing columns in dataset: ['machine_id', 'time_index', 'op_setting_1', 'op_setting_2', 'op_setting_3', 's1', 's2', 's3', 's4', 's5', 's6', 's7', 's8', 's9', 's10', 's11', 's12', 's13', 's14', 's15', 's16', 's17', 's18', 's19', 's20', 's21', 'RUL', 'anomaly_flag', 'dataset_name', 'fd_id', 'event_time']
# INFO:__main__:Data Columns List purged of core and label columns: ['op_setting_1', 'op_setting_2', 'op_setting_3', 's1', 's2', 's3', 's4', 's5', 's6', 's7', 's8', 's9', 's10', 's11', 's12', 's13', 's14', 's15', 's16', 's17', 's18', 's19', 's20', 's21']
# INFO:__main__:Column Order Set: ['dataset_name', 'fd_id', 'machine_id', 'time_index', 'event_time', 'RUL', 'anomaly_flag', 'op_setting_1', 'op_setting_2', 'op_setting_3', 's1', 's2', 's3', 's4', 's5', 's6', 's7', 's8', 's9', 's10', 's11', 's12', 's13', 's14', 's15', 's16', 's17', 's18', 's19', 's20', 's21']
# INFO:__main__:Orderd Dataframe created: None
# INFO:__main__:Orderd Dataframe appended to list of dataframes: [      dataset_name  fd_id  machine_id  time_index  event_time  RUL  anomaly_flag  op_setting_1  op_setting_2  op_setting_3      s1      s2       s3       s4     s5     s6      s7       s8       s9  \
# 0         TURBOFAN  FD001           1           1           1  191             0       -0.0007       -0.0004         100.0  518.67  641.82  1589.70  1400.60  14.62  21.61  554.36  2388.06  9046.19
# 1         TURBOFAN  FD001           1           2           2  190             0        0.0019       -0.0003         100.0  518.67  642.15  1591.82  1403.14  14.62  21.61  553.75  2388.04  9044.07
# 2         TURBOFAN  FD001           1           3           3  189             0       -0.0043        0.0003         100.0  518.67  642.35  1587.99  1404.20  14.62  21.61  554.26  2388.08  9052.94
# 3         TURBOFAN  FD001           1           4           4  188             0        0.0007        0.0000         100.0  518.67  642.35  1582.79  1401.87  14.62  21.61  554.45  2388.11  9049.48
# 4         TURBOFAN  FD001           1           5           5  187             0       -0.0019       -0.0002         100.0  518.67  642.37  1582.85  1406.22  14.62  21.61  554.00  2388.06  9055.15
# ...            ...    ...         ...         ...         ...  ...           ...           ...           ...           ...     ...     ...      ...      ...    ...    ...     ...      ...      ...
# 20626     TURBOFAN  FD001         100         196         196    4             1       -0.0004       -0.0003         100.0  518.67  643.49  1597.98  1428.63  14.62  21.61  551.43  2388.19  9065.52
# 20627     TURBOFAN  FD001         100         197         197    3             1       -0.0016       -0.0005         100.0  518.67  643.54  1604.50  1433.58  14.62  21.61  550.86  2388.23  9065.11
# 20628     TURBOFAN  FD001         100         198         198    2             1        0.0004        0.0000         100.0  518.67  643.42  1602.46  1428.18  14.62  21.61  550.94  2388.24  9065.90
# 20629     TURBOFAN  FD001         100         199         199    1             1       -0.0011        0.0003         100.0  518.67  643.23  1605.26  1426.53  14.62  21.61  550.68  2388.25  9073.72
# 20630     TURBOFAN  FD001         100         200         200    0             1       -0.0032       -0.0005         100.0  518.67  643.85  1600.38  1432.14  14.62  21.61  550.79  2388.26  9061.48
#
#        s10    s11     s12      s13      s14     s15   s16  s17   s18    s19    s20      s21
# 0      1.3  47.47  521.66  2388.02  8138.62  8.4195  0.03  392  2388  100.0  39.06  23.4190
# ...
#  22  s18           61249 non-null  int64
#  23  s19           61249 non-null  float64
#  24  s20           61249 non-null  float64
#  25  s21           61249 non-null  float64
# dtypes: float64(22), int64(4)
# memory usage: 12.1 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61249 entries, 0 to 61248
# Data columns (total 27 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   unit          61249 non-null  int64
#  1   cycle         61249 non-null  int64
#  2   op_setting_1  61249 non-null  float64
#  3   op_setting_2  61249 non-null  float64
#  4   op_setting_3  61249 non-null  float64
#  5   s1            61249 non-null  float64
#  6   s2            61249 non-null  float64
#  7   s3            61249 non-null  float64
#  8   s4            61249 non-null  float64
#  9   s5            61249 non-null  float64
#  10  s6            61249 non-null  float64
#  11  s7            61249 non-null  float64
#  12  s8            61249 non-null  float64
#  13  s9            61249 non-null  float64
#  14  s10           61249 non-null  float64
#  15  s11           61249 non-null  float64
#  16  s12           61249 non-null  float64
#  17  s13           61249 non-null  float64
#  18  s14           61249 non-null  float64
#  19  s15           61249 non-null  float64
#  20  s16           61249 non-null  float64
#  21  s17           61249 non-null  int64
#  22  s18           61249 non-null  int64
#  23  s19           61249 non-null  float64
#  24  s20           61249 non-null  float64
#  25  s21           61249 non-null  float64
#  26  max_cycle     61249 non-null  int64
# dtypes: float64(22), int64(5)
# memory usage: 12.6 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61249 entries, 0 to 61248
# Data columns (total 27 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   unit          61249 non-null  int64
#  1   cycle         61249 non-null  int64
#  2   op_setting_1  61249 non-null  float64
#  3   op_setting_2  61249 non-null  float64
#  4   op_setting_3  61249 non-null  float64
#  5   s1            61249 non-null  float64
#  6   s2            61249 non-null  float64
#  7   s3            61249 non-null  float64
#  8   s4            61249 non-null  float64
#  9   s5            61249 non-null  float64
#  10  s6            61249 non-null  float64
#  11  s7            61249 non-null  float64
#  12  s8            61249 non-null  float64
#  13  s9            61249 non-null  float64
#  14  s10           61249 non-null  float64
#  15  s11           61249 non-null  float64
#  16  s12           61249 non-null  float64
#  17  s13           61249 non-null  float64
#  18  s14           61249 non-null  float64
#  19  s15           61249 non-null  float64
#  20  s16           61249 non-null  float64
#  21  s17           61249 non-null  int64
#  22  s18           61249 non-null  int64
#  23  s19           61249 non-null  float64
#  24  s20           61249 non-null  float64
#  25  s21           61249 non-null  float64
#  26  RUL           61249 non-null  int64
# dtypes: float64(22), int64(5)
# memory usage: 12.6 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61249 entries, 0 to 61248
# Data columns (total 28 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   unit          61249 non-null  int64
#  1   cycle         61249 non-null  int64
#  2   op_setting_1  61249 non-null  float64
#  3   op_setting_2  61249 non-null  float64
#  4   op_setting_3  61249 non-null  float64
#  5   s1            61249 non-null  float64
#  6   s2            61249 non-null  float64
#  7   s3            61249 non-null  float64
#  8   s4            61249 non-null  float64
#  9   s5            61249 non-null  float64
#  10  s6            61249 non-null  float64
#  11  s7            61249 non-null  float64
#  12  s8            61249 non-null  float64
#  13  s9            61249 non-null  float64
#  14  s10           61249 non-null  float64
#  15  s11           61249 non-null  float64
#  16  s12           61249 non-null  float64
#  17  s13           61249 non-null  float64
#  18  s14           61249 non-null  float64
#  19  s15           61249 non-null  float64
#  20  s16           61249 non-null  float64
#  21  s17           61249 non-null  int64
#  22  s18           61249 non-null  int64
#  23  s19           61249 non-null  float64
#  24  s20           61249 non-null  float64
#  25  s21           61249 non-null  float64
#  26  RUL           61249 non-null  int64
#  27  anomaly_flag  61249 non-null  int64
# dtypes: float64(22), int64(6)
# memory usage: 13.1 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61249 entries, 0 to 61248
# Data columns (total 29 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   unit          61249 non-null  int64
#  1   cycle         61249 non-null  int64
#  2   op_setting_1  61249 non-null  float64
#  3   op_setting_2  61249 non-null  float64
#  4   op_setting_3  61249 non-null  float64
#  5   s1            61249 non-null  float64
#  6   s2            61249 non-null  float64
#  7   s3            61249 non-null  float64
#  8   s4            61249 non-null  float64
#  9   s5            61249 non-null  float64
#  10  s6            61249 non-null  float64
#  11  s7            61249 non-null  float64
#  12  s8            61249 non-null  float64
#  13  s9            61249 non-null  float64
#  14  s10           61249 non-null  float64
#  15  s11           61249 non-null  float64
#  16  s12           61249 non-null  float64
#  17  s13           61249 non-null  float64
#  18  s14           61249 non-null  float64
#  19  s15           61249 non-null  float64
#  20  s16           61249 non-null  float64
#  21  s17           61249 non-null  int64
#  22  s18           61249 non-null  int64
#  23  s19           61249 non-null  float64
#  24  s20           61249 non-null  float64
#  25  s21           61249 non-null  float64
#  26  RUL           61249 non-null  int64
#  27  anomaly_flag  61249 non-null  int64
#  28  dataset_name  61249 non-null  object
# dtypes: float64(22), int64(6), object(1)
# memory usage: 13.6+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61249 entries, 0 to 61248
# Data columns (total 30 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   unit          61249 non-null  int64
#  1   cycle         61249 non-null  int64
#  2   op_setting_1  61249 non-null  float64
#  3   op_setting_2  61249 non-null  float64
#  4   op_setting_3  61249 non-null  float64
#  5   s1            61249 non-null  float64
#  6   s2            61249 non-null  float64
#  7   s3            61249 non-null  float64
#  8   s4            61249 non-null  float64
#  9   s5            61249 non-null  float64
#  10  s6            61249 non-null  float64
#  11  s7            61249 non-null  float64
#  12  s8            61249 non-null  float64
#  13  s9            61249 non-null  float64
#  14  s10           61249 non-null  float64
#  15  s11           61249 non-null  float64
#  16  s12           61249 non-null  float64
#  17  s13           61249 non-null  float64
#  18  s14           61249 non-null  float64
#  19  s15           61249 non-null  float64
#  20  s16           61249 non-null  float64
#  21  s17           61249 non-null  int64
#  22  s18           61249 non-null  int64
#  23  s19           61249 non-null  float64
#  24  s20           61249 non-null  float64
#  25  s21           61249 non-null  float64
#  26  RUL           61249 non-null  int64
#  27  anomaly_flag  61249 non-null  int64
#  28  dataset_name  61249 non-null  object
#  29  fd_id         61249 non-null  object
# dtypes: float64(22), int64(6), object(2)
# memory usage: 14.0+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61249 entries, 0 to 61248
# Data columns (total 31 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   unit          61249 non-null  int64
#  1   cycle         61249 non-null  int64
#  2   op_setting_1  61249 non-null  float64
#  3   op_setting_2  61249 non-null  float64
#  4   op_setting_3  61249 non-null  float64
#  5   s1            61249 non-null  float64
#  6   s2            61249 non-null  float64
#  7   s3            61249 non-null  float64
#  8   s4            61249 non-null  float64
#  9   s5            61249 non-null  float64
#  10  s6            61249 non-null  float64
#  11  s7            61249 non-null  float64
#  12  s8            61249 non-null  float64
#  13  s9            61249 non-null  float64
#  14  s10           61249 non-null  float64
#  15  s11           61249 non-null  float64
#  16  s12           61249 non-null  float64
#  17  s13           61249 non-null  float64
#  18  s14           61249 non-null  float64
#  19  s15           61249 non-null  float64
#  20  s16           61249 non-null  float64
#  21  s17           61249 non-null  int64
#  22  s18           61249 non-null  int64
#  23  s19           61249 non-null  float64
#  24  s20           61249 non-null  float64
#  25  s21           61249 non-null  float64
#  26  RUL           61249 non-null  int64
#  27  anomaly_flag  61249 non-null  int64
#  28  dataset_name  61249 non-null  object
#  29  fd_id         61249 non-null  object
#  30  event_time    61249 non-null  int64
# dtypes: float64(22), int64(7), object(2)
# memory usage: 14.5+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61249 entries, 0 to 61248
# Data columns (total 31 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   machine_id    61249 non-null  int64
#  1   time_index    61249 non-null  int64
#  2   op_setting_1  61249 non-null  float64
#  3   op_setting_2  61249 non-null  float64
#  4   op_setting_3  61249 non-null  float64
#  5   s1            61249 non-null  float64
#  6   s2            61249 non-null  float64
#  7   s3            61249 non-null  float64
#  8   s4            61249 non-null  float64
#  9   s5            61249 non-null  float64
#  10  s6            61249 non-null  float64
#  11  s7            61249 non-null  float64
#  12  s8            61249 non-null  float64
#  13  s9            61249 non-null  float64
#  14  s10           61249 non-null  float64
#  15  s11           61249 non-null  float64
#  16  s12           61249 non-null  float64
#  17  s13           61249 non-null  float64
#  18  s14           61249 non-null  float64
#  19  s15           61249 non-null  float64
#  20  s16           61249 non-null  float64
#  21  s17           61249 non-null  int64
#  22  s18           61249 non-null  int64
#  23  s19           61249 non-null  float64
#  24  s20           61249 non-null  float64
#  25  s21           61249 non-null  float64
#  26  RUL           61249 non-null  int64
#  27  anomaly_flag  61249 non-null  int64
#  28  dataset_name  61249 non-null  object
#  29  fd_id         61249 non-null  object
#  30  event_time    61249 non-null  int64
# dtypes: float64(22), int64(7), object(2)
# memory usage: 14.5+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61249 entries, 0 to 61248
# Data columns (total 31 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   dataset_name  61249 non-null  object
#  1   fd_id         61249 non-null  object
#  2   machine_id    61249 non-null  int64
#  3   time_index    61249 non-null  int64
#  4   event_time    61249 non-null  int64
#  5   RUL           61249 non-null  int64
#  6   anomaly_flag  61249 non-null  int64
#  7   op_setting_1  61249 non-null  float64
#  8   op_setting_2  61249 non-null  float64
#  9   op_setting_3  61249 non-null  float64
#  10  s1            61249 non-null  float64
#  11  s2            61249 non-null  float64
#  12  s3            61249 non-null  float64
#  13  s4            61249 non-null  float64
#  14  s5            61249 non-null  float64
#  15  s6            61249 non-null  float64
#  16  s7            61249 non-null  float64
#  17  s8            61249 non-null  float64
#  18  s9            61249 non-null  float64
#  19  s10           61249 non-null  float64
#  20  s11           61249 non-null  float64
#  21  s12           61249 non-null  float64
#  22  s13           61249 non-null  float64
#  23  s14           61249 non-null  float64
#  24  s15           61249 non-null  float64
#  25  s16           61249 non-null  float64
#  26  s17           61249 non-null  int64
#  27  s18           61249 non-null  int64
#  28  s19           61249 non-null  float64
#  29  s20           61249 non-null  float64
#  30  s21           61249 non-null  float64
# dtypes: float64(22), int64(7), object(2)
# memory usage: 14.5+ MB
# INFO:__main__:All Dataframe concatenated into a single dataframe, vertically        dataset_name  fd_id  machine_id  time_index  event_time  RUL  anomaly_flag  op_setting_1  op_setting_2  op_setting_3      s1      s2       s3       s4     s5     s6      s7       s8       s9  \
# 0          TURBOFAN  FD001           1           1           1  191             0       -0.0007       -0.0004         100.0  518.67  641.82  1589.70  1400.60  14.62  21.61  554.36  2388.06  9046.19
# 1          TURBOFAN  FD001           1           2           2  190             0        0.0019       -0.0003         100.0  518.67  642.15  1591.82  1403.14  14.62  21.61  553.75  2388.04  9044.07
# 2          TURBOFAN  FD001           1           3           3  189             0       -0.0043        0.0003         100.0  518.67  642.35  1587.99  1404.20  14.62  21.61  554.26  2388.08  9052.94
# 3          TURBOFAN  FD001           1           4           4  188             0        0.0007        0.0000         100.0  518.67  642.35  1582.79  1401.87  14.62  21.61  554.45  2388.11  9049.48
# 4          TURBOFAN  FD001           1           5           5  187             0       -0.0019       -0.0002         100.0  518.67  642.37  1582.85  1406.22  14.62  21.61  554.00  2388.06  9055.15
# ...             ...    ...         ...         ...         ...  ...           ...           ...           ...           ...     ...     ...      ...      ...    ...    ...     ...      ...      ...
# 160354     TURBOFAN  FD004         249         251         251    4             1        9.9998        0.2500         100.0  489.05  605.33  1516.36  1315.28  10.52  15.46  404.59  2319.66  8840.16
# 160355     TURBOFAN  FD004         249         252         252    3             1        0.0028        0.0015         100.0  518.67  643.42  1598.92  1426.77  14.62  21.57  567.59  2388.47  9117.12
# 160356     TURBOFAN  FD004         249         253         253    2             1        0.0029        0.0000         100.0  518.67  643.68  1607.72  1430.56  14.62  21.57  569.04  2388.51  9126.53
# 160357     TURBOFAN  FD004         249         254         254    1             1       35.0046        0.8400         100.0  449.44  555.77  1381.29  1148.18   5.48   7.96  199.93  2223.78  8403.64
# 160358     TURBOFAN  FD004         249         255         255    0             1       42.0030        0.8400         100.0  445.00  549.85  1369.75  1147.45   3.91   5.69  142.47  2212.52  8391.31
#
#          s10    s11     s12      s13      s14     s15   s16  s17   s18    s19    s20      s21
# 0       1.30  47.47  521.66  2388.02  8138.62  8.4195  0.03  392  2388  100.0  39.06  23.4190
# 1       1.30  47.49  522.28  2388.07  8131.49  8.4318  0.03  392  2388  100.0  39.00  23.4236
# 2       1.30  47.27  522.42  2388.03  8133.23  8.4178  0.03  390  2388  100.0  38.95  23.3442
# 3       1.30  47.13  522.86  2388.08  8133.83  8.3682  0.03  392  2388  100.0  38.88  23.3739
# 4       1.30  47.28  522.19  2388.04  8133.80  8.4294  0.03  393  2388  100.0  38.90  23.4044
# ...      ...    ...     ...      ...      ...     ...   ...  ...   ...    ...    ...      ...
# 160354  1.27  46.08  380.16  2388.73  8185.69  8.4541  0.03  372  2319  100.0  29.11  17.5234
# 160355  1.31  48.04  535.02  2388.46  8185.47  8.2221  0.03  396  2388  100.0  39.38  23.7151
# 160356  1.31  48.24  535.41  2388.48  8193.94  8.2525  0.03  395  2388  100.0  39.78  23.8270
# 160357  1.05  42.53  187.92  2388.83  8125.64  9.0515  0.02  337  2223  100.0  15.26   9.0774
# 160358  1.05  42.60  134.32  2388.66  8144.33  9.1207  0.02  333  2212  100.0  10.66   6.4341
#
# [160359 rows x 31 columns]

# %%
bronze_dfs.shape
# Out:
# (160359, 31)

# %%
bronze_dfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160359 entries, 0 to 160358
# Data columns (total 31 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   dataset_name  160359 non-null  object
#  1   fd_id         160359 non-null  object
#  2   machine_id    160359 non-null  int64
#  3   time_index    160359 non-null  int64
#  4   event_time    160359 non-null  int64
#  5   RUL           160359 non-null  int64
#  6   anomaly_flag  160359 non-null  int64
#  7   op_setting_1  160359 non-null  float64
#  8   op_setting_2  160359 non-null  float64
#  9   op_setting_3  160359 non-null  float64
#  10  s1            160359 non-null  float64
#  11  s2            160359 non-null  float64
#  12  s3            160359 non-null  float64
#  13  s4            160359 non-null  float64
#  14  s5            160359 non-null  float64
#  15  s6            160359 non-null  float64
#  16  s7            160359 non-null  float64
#  17  s8            160359 non-null  float64
#  18  s9            160359 non-null  float64
#  19  s10           160359 non-null  float64
#  20  s11           160359 non-null  float64
#  21  s12           160359 non-null  float64
#  22  s13           160359 non-null  float64
#  23  s14           160359 non-null  float64
#  24  s15           160359 non-null  float64
#  25  s16           160359 non-null  float64
#  26  s17           160359 non-null  int64
#  27  s18           160359 non-null  int64
#  28  s19           160359 non-null  float64
#  29  s20           160359 non-null  float64
#  30  s21           160359 non-null  float64
# dtypes: float64(22), int64(7), object(2)
# memory usage: 37.9+ MB

# %%
bronze_dfs.head(10)
# Out:
#   dataset_name  fd_id  machine_id  time_index  event_time  RUL  anomaly_flag  op_setting_1  op_setting_2  op_setting_3      s1      s2       s3       s4     s5     s6      s7       s8       s9  s10  \
# 0     TURBOFAN  FD001           1           1           1  191             0       -0.0007       -0.0004         100.0  518.67  641.82  1589.70  1400.60  14.62  21.61  554.36  2388.06  9046.19  1.3
# 1     TURBOFAN  FD001           1           2           2  190             0        0.0019       -0.0003         100.0  518.67  642.15  1591.82  1403.14  14.62  21.61  553.75  2388.04  9044.07  1.3
# 2     TURBOFAN  FD001           1           3           3  189             0       -0.0043        0.0003         100.0  518.67  642.35  1587.99  1404.20  14.62  21.61  554.26  2388.08  9052.94  1.3
# 3     TURBOFAN  FD001           1           4           4  188             0        0.0007        0.0000         100.0  518.67  642.35  1582.79  1401.87  14.62  21.61  554.45  2388.11  9049.48  1.3
# 4     TURBOFAN  FD001           1           5           5  187             0       -0.0019       -0.0002         100.0  518.67  642.37  1582.85  1406.22  14.62  21.61  554.00  2388.06  9055.15  1.3
# 5     TURBOFAN  FD001           1           6           6  186             0       -0.0043       -0.0001         100.0  518.67  642.10  1584.47  1398.37  14.62  21.61  554.67  2388.02  9049.68  1.3
# 6     TURBOFAN  FD001           1           7           7  185             0        0.0010        0.0001         100.0  518.67  642.48  1592.32  1397.77  14.62  21.61  554.34  2388.02  9059.13  1.3
# 7     TURBOFAN  FD001           1           8           8  184             0       -0.0034        0.0003         100.0  518.67  642.56  1582.96  1400.97  14.62  21.61  553.85  2388.00  9040.80  1.3
# 8     TURBOFAN  FD001           1           9           9  183             0        0.0008        0.0001         100.0  518.67  642.12  1590.98  1394.80  14.62  21.61  553.69  2388.05  9046.46  1.3
# 9     TURBOFAN  FD001           1          10          10  182             0       -0.0033        0.0001         100.0  518.67  641.71  1591.24  1400.46  14.62  21.61  553.59  2388.05  9051.70  1.3
#
#      s11     s12      s13      s14     s15   s16  s17   s18    s19    s20      s21
# 0  47.47  521.66  2388.02  8138.62  8.4195  0.03  392  2388  100.0  39.06  23.4190
# 1  47.49  522.28  2388.07  8131.49  8.4318  0.03  392  2388  100.0  39.00  23.4236
# 2  47.27  522.42  2388.03  8133.23  8.4178  0.03  390  2388  100.0  38.95  23.3442
# 3  47.13  522.86  2388.08  8133.83  8.3682  0.03  392  2388  100.0  38.88  23.3739
# 4  47.28  522.19  2388.04  8133.80  8.4294  0.03  393  2388  100.0  38.90  23.4044
# 5  47.16  521.68  2388.03  8132.85  8.4108  0.03  391  2388  100.0  38.98  23.3669
# 6  47.36  522.32  2388.03  8132.32  8.3974  0.03  392  2388  100.0  39.10  23.3774
# 7  47.24  522.47  2388.03  8131.07  8.4076  0.03  391  2388  100.0  38.97  23.3106
# 8  47.29  521.79  2388.05  8125.69  8.3728  0.03  392  2388  100.0  39.05  23.4066
# 9  47.03  521.79  2388.06  8129.38  8.4286  0.03  393  2388  100.0  38.95  23.4694

# %%
bronze_dfs.to_csv(BRONZE_DATA_OUTPUT_PATH, index=False)
