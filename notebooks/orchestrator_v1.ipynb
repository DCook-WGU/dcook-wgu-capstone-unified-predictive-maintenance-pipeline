# %%
# Reference: https://stackoverflow.com/questions/49817409/running-a-jupyter-notebook-from-another-notebook

# %run ./preprocessing/EDA_Notebook_Pump_Bronze_01_Preprocessing.ipynb

# %%
# %run ./eda/EDA_Notebook_Pump_Silver_01_PreEDA.ipynb

# %%
# %run ./eda/EDA_Notebook_Pump_Silver_02_EDA.ipynb

# %%
# %run ./experiments/EDA_Notebook_Pump_Gold_01_PreProcessing.ipynb

# %%
# %run ./experiments/EDA_Notebook_Pump_Gold_02_Baseline_Modeling.ipynb

# %%
# %run ./experiments/EDA_Notebook_Pump_Gold_03a_Cascade_Modeling.ipynb

# %%
# %run ./experiments/EDA_Notebook_Pump_Gold_03b_Cascade_Modeling.ipynb

# %%
# %run ./experiments/EDA_Notebook_Pump_Gold_03c_Cascade_Modeling.ipynb

# %%
# %run ./experiments/EDA_Notebook_Pump_Gold_04_Comparision.ipynb

# %%
# %run ./experiments/EDA_Notebook_Pump_Gold_05_Anomaly_Detection.ipynb
